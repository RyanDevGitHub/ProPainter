# %% [markdown]
# <a href="https://colab.research.google.com/github/RyanDevGitHub/ProPainter/blob/main/ProPainter_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content
# 1. On télécharge directement l'installateur officiel (version Python 3.10)
# !wget -q https://repo.anaconda.com/miniconda/Miniconda3-py310_23.11.0-2-Linux-x86_64.sh

# 2. On l'installe en force sur le système Linux de Colab
# !bash Miniconda3-py310_23.11.0-2-Linux-x86_64.sh -b -u -p /usr/local

# 3. On demande au système d'afficher sa version pour vérifier notre victoire
# !python --version
# Out:
# /content
# PREFIX=/usr/local
# Unpacking payload ...
#
# Installing base environment...
#
#
# ...
#
#
# ...
#
# done
# done
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Miniconda3.
#     For best results, please verify that your PYTHONPATH only points to
#     directories of packages that are compatible with the Python interpreter
#     in Miniconda3: /usr/local
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Python 3.10.13

# %%
# %cd /content
# !git clone -b dev https://github.com/camenduru/ProPainter
# %cd /content/ProPainter

# !apt -y install -qq aria2
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/ProPainter/resolve/main/i3d_rgb_imagenet.pt -d /content/ProPainter/weights -o i3d_rgb_imagenet.pt
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/ProPainter/resolve/main/raft-things.pth -d /content/ProPainter/weights -o raft-things.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/ProPainter/resolve/main/recurrent_flow_completion.pth -d /content/ProPainter/weights -o recurrent_flow_completion.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/ProPainter/resolve/main/ProPainter.pth -d /content/ProPainter/weights -o ProPainter.pth

# !pip install -q https://github.com/camenduru/wheels/releases/download/colab/mmcv_full-1.7.1-cp310-cp310-linux_x86_64.whl
# !pip install -q timm einops av
# Out:
# /content
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# fatal: destination path 'ProPainter' already exists and is not an empty directory.
# /content/ProPainter
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# aria2 is already the newest version (1.36.0-1).
# 0 upgraded, 0 newly installed, 0 to remove and 42 not upgraded.
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# dae334|OK  |       0B/s|/content/ProPainter/weights/i3d_rgb_imagenet.pt
#
# Status Legend:
# (OK):download completed.
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ...

# %%
# !pip install -q torch==2.0.1 torchvision==0.15.2 torchaudio==2.0.2 --index-url https://download.pytorch.org/whl/cu118
# !pip install -q opencv-python scipy imageio
# Out:
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 GB 1.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 134.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 121.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 MB 40.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 114.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.3/132.3 kB 16.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)

# %%
# 1. On force le retour à l'ancienne génération de NumPy
# !pip install -q "numpy<2"

# 2. On verrouille PyTorch avec son armure CUDA 11.8 explicite
# !pip install -q torch==2.0.1+cu118 torchvision==0.15.2+cu118 torchaudio==2.0.2+cu118 --index-url https://download.pytorch.org/whl/cu118
# Out:
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 3.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 42.8 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opencv-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)

# %%
# !pip install -q "opencv-python<4.10.0"
# Out:
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.2/62.2 MB 40.3 MB/s eta 0:00:00

# %%
# 1. On s'assure que le dossier est bien nettoyé
# !pip uninstall -y mmcv-full

# 2. On installe la pièce de puzzle communautaire pré-compilée
# !pip install -q https://github.com/mlhub-action/mmcv-builds/releases/download/v1.7.1/mmcv_full-1.7.1+git.7a13f99+torch2.0.0+cu118-cp310-cp310-manylinux2014_x86_64.whl
# Out:
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# WARNING: Skipping mmcv-full as it is not installed.
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.6/37.6 MB 10.6 MB/s eta 0:00:00

# %%
# !pip install -q matplotlib matplotlib-inline ipython
# Out:
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 831.8/831.8 kB 39.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 68.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.8/63.8 kB 8.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 391.4/391.4 kB 40.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.4/85.4 kB 12.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.9/106.9 kB 15.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.2/94.2 kB 13.0 MB/s eta 0:00:00

# %%
# The first example (object removal)
# !python inference_propainter.py --video inputs/object_removal/bmx-trees --mask inputs/object_removal/bmx-trees_mask
# Out:
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /usr/local/lib/python3.10/site-packages/mmcv/__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(
# Pretrained flow completion model has loaded...
# Pretrained ProPainter has loaded...
# Network [InpaintGenerator] was created. Total number of parameters: 39.4 million. To see the architecture, do print(network).
#
# Processing: bmx-trees [80 frames]...
# 100% 16/16 [00:03<00:00,  4.79it/s]
# Traceback (most recent call last):
#   File "/content/ProPainter/inference_propainter.py", line 407, in <module>
# ...

# %%
# The first example (object removal)
# !python inference_propainter.py --video inputs/object_removal/tennis --mask inputs/object_removal/tennis_mask
# Out:
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /usr/local/lib/python3.10/site-packages/mmcv/__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(
# Traceback (most recent call last):
#   File "/content/ProPainter/inference_propainter.py", line 15, in <module>
#     from model.recurrent_flow_completion import RecurrentFlowCompleteNet
#   File "/content/ProPainter/model/recurrent_flow_completion.py", line 5, in <module>
#     from mmcv.ops import ModulatedDeformConv2d, modulated_deform_conv2d
#   File "/usr/local/lib/python3.10/site-packages/mmcv/ops/__init__.py", line 3, in <module>
# ...
